# %% [markdown]
# # Seaborn Visualization - Homework 1 (Basic)
#
# Fill in the code in each cell below to generate the required plots.
# Refer to the Seaborn documentation or lecture notes if you get stuck.

# %% [markdown]
# ## 1. Setup
#
# Import the required libraries below.

# %%
# TODO: import seaborn as sns, matplotlib.pyplot as plt, pandas as pd, numpy as np

# %% [markdown]
# ## 2. Load Dataset
#
# Load the `tips` dataset using `sns.load_dataset()` and display the first 5 rows.

# %%
# TODO: load the 'tips' dataset and print the head
# tips = ...

# %% [markdown]
# ## 3. Scatter Plot
#
# Create a scatter plot of `total_bill` vs `tip`. Use `hue='day'` to color by day of the week.

# %%
# TODO: sns.scatterplot(...)
# plt.title(...)
# plt.show()

# %% [markdown]
# ## 4. Line Plot
#
# Create a line plot of a sine wave: `x = np.linspace(0, 10, 100)`, `y = np.sin(x)`.
# Add a label and legend.

# %%
# TODO: create x and y arrays
# TODO: sns.lineplot(...)
# TODO: add title, legend, show

# %% [markdown]
# ## 5. Histogram
#
# Create a histogram of the `total_bill` column with a KDE curve overlay and 20 bins.

# %%
# TODO: sns.histplot(...)
# plt.title(...)
# plt.show()

# %% [markdown]
# ## 6. Box Plot
#
# Create a box plot of `total_bill` grouped by `day`.

# %%
# TODO: sns.boxplot(...)

# %% [markdown]
# ## 7. Violin Plot
#
# Create a violin plot of `tip` grouped by `day`, split by `sex`.

# %%
# TODO: sns.violinplot(...)

# %% [markdown]
# ## 8. Pair Plot
#
# Create a pair plot of the `tips` dataset, colored by `sex`.

# %%
# TODO: sns.pairplot(...)

# %% [markdown]
# ## 9. Heatmap
#
# Compute the correlation matrix of `['total_bill', 'tip', 'size']` and display it as a heatmap with annotations.

# %%
# TODO: compute correlation matrix
# corr = ...
# TODO: sns.heatmap(corr, annot=True, ...)

# %% [markdown]
# ## 10. Customization
#
# Set the theme to `"darkgrid"`, then create a histogram of `total_bill` with a KDE.

# %%
# TODO: sns.set_theme(style="darkgrid")
# TODO: sns.histplot(...)

# %% [markdown]
# ## 11. Custom Figure Size
#
# Create a box plot of `total_bill` by `day` with a figure size of `(10, 6)`.

# %%
# TODO: plt.figure(figsize=(10, 6))
# TODO: sns.boxplot(...)

# %% [markdown]
# ## 12. Overlayed Histograms
#
# Overlay two histograms on the same figure:
# - `total_bill` in blue with alpha=0.5
# - `tip` in red with alpha=0.5
# Add a legend.

# %%
# TODO: first histplot
# TODO: second histplot
# TODO: plt.legend(), plt.title(), plt.show()

# %% [markdown]
# ## 13. Joint Plot
#
# Create a joint plot of `total_bill` vs `tip` with a regression line (`kind='reg'`).

# %%
# TODO: sns.jointplot(...)

# %% [markdown]
# ## 14. Facet Grid
#
# Create a FacetGrid with columns by `day`, hue by `sex`, and map a scatter plot of `total_bill` vs `tip`.

# %%
# TODO: g = sns.FacetGrid(...)
# TODO: g.map(...).add_legend()
# TODO: plt.show()

# %% [markdown]
# ## 15. Challenge Exercise
#
# Load the `iris` dataset (`sns.load_dataset('iris')`). Create:
# 1. A pair plot colored by `species`
# 2. A heatmap of the correlation matrix of sepal/petal measurements
# 3. A box plot of `petal_length` grouped by `species`
#
# Write all three plots below.

# %%
# TODO: iris = sns.load_dataset('iris')
# 1. Pair plot
# 2. Heatmap
# 3. Box plot
