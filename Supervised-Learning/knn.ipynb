# %% [markdown]
# # K-Nearest Neighbors (KNN) Classifier & Regressor
#
# **K-Nearest Neighbors (KNN)** is a simple, non-parametric, instance-based learning algorithm used for both classification and regression.
#
# We will:
# 1. Implement KNN **from scratch** to understand the algorithm
# 2. Use KNN for **classification** on the Iris dataset
# 3. Use KNN for **regression** on a synthetic dataset
# 4. Tune hyperparameters (K, distance metric, weighting)

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from sklearn.datasets import load_iris, make_regression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error

print("All libraries imported successfully")

# %% [markdown]
# ---
# ## 1. Distance Metrics
#
# KNN relies on distance calculations. We'll implement two common distance metrics:
#
# - **Euclidean Distance**: $d(\mathbf{x}, \mathbf{y}) = \sqrt{\sum_{i=1}^{n} (x_i - y_i)^2}$
# - **Manhattan Distance**: $d(\mathbf{x}, \mathbf{y}) = \sum_{i=1}^{n} |x_i - y_i|$

# %%
def euclidean_distance(x1, x2):
    """Compute Euclidean distance between two points."""
    # TODO: Implement Euclidean distance
    # Hint: use np.sqrt and np.sum
    pass

def manhattan_distance(x1, x2):
    """Compute Manhattan distance between two points."""
    # TODO: Implement Manhattan distance
    # Hint: use np.sum and np.abs
    pass

# Quick test
a = np.array([0, 0])
b = np.array([3, 4])
print(f"Euclidean distance between {a} and {b}: {euclidean_distance(a, b):.2f}")
print(f"Manhattan distance between {a} and {b}: {manhattan_distance(a, b):.2f}")

# %% [markdown]
# ---
# ## 2. Implement KNN from Scratch
#
# ### Algorithm Steps:
# 1. **Choose K** (number of neighbors)
# 2. For a test point, **compute distances** to all training points
# 3. **Sort** distances and select the K nearest neighbors
# 4. **Predict**:
#    - **Classification**: majority vote among K neighbors
#    - **Regression**: average of the K neighbors' values

# %%
class KNN:
    """K-Nearest Neighbors from scratch."""
    
    def __init__(self, k=3, distance_metric='euclidean'):
        self.k = k
        self.distance_metric = distance_metric
    
    def fit(self, X, y):
        """Store the training data (KNN is a lazy learner)."""
        # TODO: Store X as self.X_train and y as self.y_train
        pass
    
    def _distance(self, x1, x2):
        """Compute distance between two points using the chosen metric."""
        # TODO: Use euclidean_distance or manhattan_distance
        pass
    
    def _predict_one(self, x):
        """Predict label/value for a single point."""
        # TODO:
        # 1. Compute distances from x to all training points
        # 2. Get indices of the k smallest distances (use np.argsort)
        # 3. Get the labels/values of the k nearest neighbors
        # 4. For classification: return majority vote
        #    For regression: return mean of neighbor values
        pass
    
    def predict(self, X):
        """Predict labels/values for multiple points."""
        # TODO: Call _predict_one for each row in X
        pass

# %% [markdown]
# ---
# ## 3. Test Custom KNN on Synthetic Data
#
# Let's create a simple binary classification dataset to verify our implementation.

# %%
# Generate synthetic 2D data
np.random.seed(42)
X_synth = np.random.randn(40, 2)
y_synth = (X_synth[:, 0] + X_synth[:, 1] > 0).astype(int)

# TODO: Split into train (80%) and test (20%) using train_test_split
X_train_s, X_test_s, y_train_s, y_test_s = # TODO

# TODO: Create a KNN instance with k=3, fit, and predict on test set
knn_custom = # TODO
# TODO: fit
# TODO: predict

# TODO: Print accuracy
print(f"Custom KNN Accuracy: ...")

# %%
# Visualize decision boundary
# TODO: Create a mesh grid and plot the decision boundary
# Hint: Use np.meshgrid, predict on the grid, then plt.contourf

x_min, x_max = X_synth[:, 0].min() - 1, X_synth[:, 0].max() + 1
y_min, y_max = X_synth[:, 1].min() - 1, X_synth[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# TODO: Predict on the mesh grid and reshape for contourf
# Z = ...

plt.figure(figsize=(8, 6))
# TODO: Plot decision boundary with plt.contourf
# TODO: Scatter plot training points
# TODO: Scatter plot test points with different markers
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Custom KNN Decision Boundary (k=3)")
plt.show()

# %% [markdown]
# ---
# ## 4. KNN for Classification with scikit-learn
#
# Now use the Iris dataset with scikit-learn's optimized `KNeighborsClassifier`.

# %%
# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("Feature shape:", X.shape)
print("Class distribution:", np.bincount(y))

# %%
# TODO: Split into train (80%) and test (20%) with stratify=y and random_state=42
X_train, X_test, y_train, y_test = # TODO

# TODO: Standardize features using StandardScaler
scaler = StandardScaler()
X_train_scaled = # TODO
X_test_scaled = # TODO

print(f"Train: {X_train.shape[0]} samples, Test: {X_test.shape[0]} samples")

# %%
# TODO: Create a KNeighborsClassifier with k=5 and fit on scaled training data
knn_clf = # TODO
# TODO: fit

# TODO: Predict on scaled test data
y_pred = # TODO

# TODO: Print accuracy score and classification report
print(f"Accuracy: ...")
print()
# TODO: classification_report

# %%
# TODO: Display confusion matrix as a heatmap
cm = # TODO

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=iris.target_names,
            yticklabels=iris.target_names)
plt.title('Confusion Matrix - KNN (k=5)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ---
# ## 5. KNN for Regression
#
# KNN can also predict continuous values by averaging the target values of K neighbors.

# %%
# Generate synthetic regression data
X_reg, y_reg = make_regression(n_samples=200, n_features=1, noise=15, random_state=42)

# TODO: Split into train (80%) and test (20%)
X_train_r, X_test_r, y_train_r, y_test_r = # TODO

# TODO: Create and fit a KNeighborsRegressor with k=5
knn_reg = # TODO
# TODO: fit

# TODO: Predict on test set
y_pred_r = # TODO

# TODO: Print mean squared error
mse = # TODO
print(f"Mean Squared Error: {mse:.2f}")

# %%
# TODO: Plot regression results
# - Scatter plot of test data points
# - Line plot of predictions (sorted by X)

plt.figure(figsize=(10, 6))

# TODO: Sort test data by X for clean line plot
sort_idx = # TODO
X_test_sorted = # TODO
y_pred_sorted = # TODO

# TODO: Scatter true test values
# TODO: Plot predicted values as a line
plt.xlabel("Feature")
plt.ylabel("Target")
plt.title("KNN Regression (k=5)")
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 6. Hyperparameter Tuning: Finding the Best K
#
# Small K → overfitting (noisy). Large K → underfitting (too smooth).
# We'll use cross-validation to find the optimal K.

# %%
# TODO: Evaluate KNN with different K values using cross-validation
k_values = range(1, 31)
cv_scores = []

for k in k_values:
    # TODO: Create a KNeighborsClassifier with current k
    knn = # TODO
    # TODO: Use cross_val_score with cv=5 on scaled data
    scores = # TODO
    cv_scores.append(scores.mean())

# TODO: Find the best K
best_k = # TODO
print(f"Best K: {best_k} (accuracy: {max(cv_scores):.4f})")

# %%
# TODO: Plot K vs cross-validation accuracy
plt.figure(figsize=(10, 5))
# TODO: plot k_values vs cv_scores
# TODO: mark the best K with a red dot
plt.xlabel("K (Number of Neighbors)")
plt.ylabel("Cross-Validation Accuracy")
plt.title("KNN: Choosing K with Cross-Validation")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## 7. Compare Custom KNN vs scikit-learn KNN

# %%
# TODO: Compare your custom KNN with scikit-learn on the synthetic data
# 1. Create and fit your custom KNN with k=3
# 2. Create and fit sklearn KNeighborsClassifier with k=3
# 3. Compare predictions (are they the same?)

knn_custom = KNN(k=3)
# TODO: fit and predict

knn_sklearn = KNeighborsClassifier(n_neighbors=3)
# TODO: fit and predict

# TODO: Check if predictions match
match = # TODO
print(f"Predictions match: {match}")

# %% [markdown]
# ---
# ## Summary
#
# | Task | Implementation |
# |---|---|
# | Custom KNN | `KNN(k, distance_metric)` class with `fit` / `predict` |
# | Distance metrics | `euclidean_distance()`, `manhattan_distance()` |
# | Classification | `sklearn.neighbors.KNeighborsClassifier()` |
# | Regression | `sklearn.neighbors.KNeighborsRegressor()` |
# | Hyperparameter tuning | `cross_val_score()` over different K values |
#
# **Key takeaways:**
# - KNN is a **lazy learner** — it stores training data and computes predictions on the fly.
# - **Feature scaling** is essential because KNN relies on distance calculations.
# - Small K → **overfitting**, large K → **underfitting** (bias-variance tradeoff).
# - KNN can be used for both **classification** (majority vote) and **regression** (mean).
