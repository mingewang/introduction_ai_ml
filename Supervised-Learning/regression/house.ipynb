# %% [markdown]
# # House Price Prediction with Linear Regression
#
# Using the **Ames Housing** dataset to predict sale price based on above-grade living area (`Gr Liv Area`).

# %% [markdown]
# ## Step 1: Install Required Libraries

# %%
# !pip install pandas matplotlib scikit-learn

# %% [markdown]
# ## Step 2: Load the Dataset
#
# Import the required libraries and load the data from the remote CSV URL.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mingewang/introduction_ai_ml/main/dataset/AmesHousing.csv"
# TODO: Load the CSV into a DataFrame named 'df'
df = None

# TODO: Print the shape of the dataset and display the first 5 rows
print(df.shape)
df.head()

# %% [markdown]
# We use `Gr Liv Area` (above-grade living area in sq ft) as the feature and `SalePrice` as the target.

# %%
# TODO: Select only 'Gr Liv Area' and 'SalePrice' columns, drop missing values, and make a copy
# Name the columns 'Size (sqft)' and 'Price'
data = None

# TODO: Print statistics with describe() and display the first 5 rows
print(data.describe())
data.head()

# %% [markdown]
# ## Step 3: Visualize the Data
#
# Create a scatter plot of house size vs. sale price.

# %%
import matplotlib.pyplot as plt

# TODO: Create a scatter plot with Size (sqft) on x-axis and Price on y-axis
# Add a title, axis labels, and grid
plt.figure(figsize=(8, 5))
plt.scatter(data['Size (sqft)'], data['Price'], color='blue', alpha=0.4, edgecolors='k', linewidth=0.5)
plt.title('')  # TODO: Add title
plt.xlabel('')  # TODO: Add x-axis label
plt.ylabel('')  # TODO: Add y-axis label
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step 4: Train the Linear Regression Model
#
# Separate the feature and target, then fit a linear regression model.

# %%
from sklearn.linear_model import LinearRegression

# TODO: Define feature matrix X (2D) and target vector y
X = None
y = None

# TODO: Initialize and train the model
model = None
model.fit(X, y)

# TODO: Retrieve and print the slope (coefficient) and intercept
slope = None
intercept = None
print(f"Slope (m): {slope:.2f}")
print(f"Intercept (b): {intercept:.2f}")
print(f"Equation: Price = {slope:.2f} * Size + {intercept:.2f}")

# %% [markdown]
# ## Step 5: Make Predictions
#
# Use the trained model to predict house prices.

# %%
# TODO: Predict the price for a 1500 sqft house and print the result
predicted_price = None
print(f"Predicted price for 1500 sqft: ${predicted_price[0]:,.2f}")

# %%
# TODO: Predict prices for multiple house sizes [1000, 1500, 2000, 2500, 3000] and print each
sizes = [1000, 1500, 2000, 2500, 3000]
predictions = None
for sqft, price in zip(sizes, predictions):
    print(f"{sqft:>5} sqft -> ${price:,.2f}")

# %% [markdown]
# ## Step 6: Plot the Regression Line
#
# Overlay the regression line on the original data points.

# %%
import numpy as np

plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='blue', alpha=0.3, edgecolors='k', linewidth=0.5, label='Actual Data')

# TODO: Generate 100 evenly spaced x-values from min to max size
x_line = np.linspace(X.min().iloc[0], X.max().iloc[0], 100)
# TODO: Predict y-values for those x-values
y_line = None
plt.plot(x_line, y_line, color='red', linewidth=2, label='Regression Line')

plt.title('Linear Regression: Living Area vs Sale Price')
plt.xlabel('Size (sqft)')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step 7: Evaluation Metrics
#
# Evaluate the model using Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R² Score.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# TODO: Generate predictions on the training data
y_pred = None

# TODO: Calculate MSE, RMSE, and R² score
mse = None
rmse = None
r2 = None

print(f"Mean Squared Error (MSE): ${mse:,.2f}")
print(f"Root Mean Squared Error (RMSE): ${rmse:,.2f}")
print(f"R² Score: {r2:.4f}")

# %% [markdown]
# ## Challenge Exercise 1: Predict price for 2000 sqft and 3000 sqft

# %%
# TODO: Use the trained model to predict prices for 2000 sqft and 3000 sqft
for size in [2000, 3000]:
    pass

# %% [markdown]
# ## Challenge Exercise 2: Multiple Linear Regression
#
# Add `Total Bsmt SF` (total basement area) as a second feature and train a multiple linear regression model.

# %%
from sklearn.linear_model import LinearRegression

# TODO: Select 'Gr Liv Area', 'Total Bsmt SF', and 'SalePrice' from df, drop missing values
# Rename columns appropriately
multi = None

# TODO: Define X_multi (2 features) and y_multi
X_multi = None
y_multi = None

# TODO: Initialize and train the model, print coefficients and R² score

# %% [markdown]
# ## Challenge Exercise 3: Compare Multiple Models
#
# Train **Linear Regression**, **Decision Tree**, and **Random Forest** on the same single feature (`Gr Liv Area`) and compare their R² scores.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# TODO: Initialize LinearRegression, DecisionTreeRegressor(random_state=42),
# and RandomForestRegressor(random_state=42)
models = {
    'Linear Regression': None,
    'Decision Tree': None,
    'Random Forest': None
}

# TODO: Train each model on X, y, predict, and print the R² score
for name, model in models.items():
    pass

# %% [markdown]
# ## Challenge Exercise 4: Polynomial Regression
#
# Use `PolynomialFeatures` to capture non-linear relationships between size and price.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# TODO: Try polynomial degrees 2 and 3, print R² score and predicted price for 2000 sqft
for degree in [2, 3]:
    pass
