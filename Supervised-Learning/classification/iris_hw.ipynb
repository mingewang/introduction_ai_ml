# %% [markdown]
# # scikit-learn Classification with Iris Dataset
#
# **scikit-learn** (sklearn) is a popular Python library providing simple and efficient tools for data mining and machine learning.
#
# The **Iris dataset** is a classic benchmark: 150 samples of iris flowers across 3 species (Setosa, Versicolor, Virginica), each with 4 features (sepal length, sepal width, petal length, petal width in cm).
#
# We will:
# 1. Load & explore the data
# 2. Split into train/test sets
# 3. Train a classifier
# 4. Evaluate performance
# 5. Experiment with preprocessing and pipelines
# 6. Compare multiple models

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import make_pipeline

print("All libraries imported successfully")

# %% [markdown]
# ---
# ## 1. Load and Explore the Iris Dataset

# %%
# TODO: Load the iris dataset using load_iris()
# Assign features to X and labels to y
iris = load_iris()
X = # TODO
y = # TODO

print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)
print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("Target distribution:", np.bincount(y))

# %%
# TODO: Create a DataFrame with feature columns and a 'species' column
# Hint: use pd.DataFrame() and pd.Categorical.from_codes()
df = # TODO

df.head(10)

# %%
# TODO: Use the .describe() method to see basic statistics
# TODO

# %%
# TODO: Create a pairplot of the DataFrame, colored by species
# Hint: use sns.pairplot() with hue='species'
# TODO

# %% [markdown]
# ---
# ## 2. Split into Train and Test Sets

# %%
# TODO: Use train_test_split() with test_size=0.2, random_state=42, stratify=y
X_train, X_test, y_train, y_test = # TODO

print(f"Train size: {X_train.shape[0]} samples")
print(f"Test size:  {X_test.shape[0]} samples")
print(f"Train class distribution: {np.bincount(y_train)}")
print(f"Test class distribution:  {np.bincount(y_test)}")

# %% [markdown]
# ---
# ## 3. Train a Logistic Regression Classifier

# %%
# TODO: Create a LogisticRegression model with max_iter=200 and fit it
model = # TODO
# TODO: model.fit(...)

# TODO: Predict on X_test
y_pred = # TODO

print("Predictions:", y_pred)
print("Actual:     ", y_test)

# %%
# TODO: Print accuracy score and classification report
# TODO: accuracy_score(y_test, y_pred)
# TODO: classification_report(y_test, y_pred, target_names=iris.target_names)

# %%
# TODO: Compute and display a confusion matrix as a heatmap
# Hint: confusion_matrix(), sns.heatmap()
# TODO

# %% [markdown]
# ---
# ## 4. Feature Scaling
#
# Many algorithms (SVM, KNN, Logistic Regression) perform better when features are on a similar scale.

# %%
# TODO: Use StandardScaler to fit_transform X_train and transform X_test
scaler = StandardScaler()
X_train_scaled = # TODO
X_test_scaled = # TODO

print("Original mean:", X_train.mean(axis=0).round(2))
print("Scaled mean:  ", X_train_scaled.mean(axis=0).round(2))
print("Scaled std:   ", X_train_scaled.std(axis=0).round(2))

# %%
# TODO: Train a new LogisticRegression on the scaled data and evaluate accuracy
# TODO

# %% [markdown]
# ---
# ## 5. Pipeline: Combine Preprocessing + Model
#
# Using `make_pipeline` chains scaling and training into a single object — cleaner code and prevents data leakage.

# %%
# TODO: Create a pipeline with StandardScaler and LogisticRegression using make_pipeline()
# TODO: Fit the pipeline on X_train and score it on X_test
pipeline = # TODO
# TODO: pipeline.fit(...)

print("Pipeline test accuracy:", pipeline.score(X_test, y_test))

# %% [markdown]
# ---
# ## 6. Compare Multiple Classifiers
#
# Experiment with different algorithms and compare their accuracy.

# %%
# TODO: Create a dictionary of classifiers (LogisticRegression, KNeighborsClassifier,
#        DecisionTreeClassifier, RandomForestClassifier, SVC)
# TODO: Use cross_val_score with a pipeline (StandardScaler + classifier) for each one
classifiers = {
    # TODO: add classifiers
}

results = {}
for name, clf in classifiers.items():
    pipe = make_pipeline(StandardScaler(), clf)
    scores = cross_val_score(pipe, X, y, cv=5, scoring='accuracy')
    results[name] = scores
    print(f"{name:25s} -> Accuracy: {scores.mean():.4f} (±{scores.std():.4f})")

# %%
# TODO: Create a boxplot comparing the cross-validation accuracy of all classifiers
# Hint: pd.DataFrame(results), sns.boxplot()
# TODO

# %% [markdown]
# ---
# ## Summary
#
# | Task | Class / Function |
# |---|---|
# | Load dataset | `sklearn.datasets.load_iris()` |
# | Train/test split | `train_test_split()` |
# | Feature scaling | `StandardScaler()` |
# | Classification | `LogisticRegression()`, `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `RandomForestClassifier()`, `SVC()` |
# | Evaluation | `accuracy_score()`, `classification_report()`, `confusion_matrix()` |
# | Pipeline | `make_pipeline()` |
# | Cross-validation | `cross_val_score()` |
#
# **Key takeaways:**
# - Always split data before preprocessing to avoid data leakage.
# - Scaling often improves model performance, especially for distance-based algorithms.
# - Pipelines keep code clean and safe.
# - Cross-validation gives a more reliable estimate of model performance than a single split.
