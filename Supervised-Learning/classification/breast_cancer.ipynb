# %% [markdown]
# # Binary Classification: Breast Cancer (Malignant vs Benign)
#
# The **Breast Cancer Wisconsin dataset** contains 569 samples of fine needle aspirates (FNA) of breast masses, with 30 numerical features computed from digitized images. The goal is to predict whether a tumor is **malignant** (cancerous) or **benign** (non-cancerous).
#
# We will:
# 1. Load & explore the data
# 2. Split into train/test sets
# 3. Train three different classifiers
# 4. Evaluate and compare performance
# 5. (Bonus) Cross-validation, feature scaling, decision boundary

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("All libraries imported successfully")

# %% [markdown]
# ---
# ## Part 1: Load and Explore the Data

# %%
# TODO: Load the breast cancer dataset using load_breast_cancer()
# Assign features to X and labels to y
data = load_breast_cancer()
X = # TODO
y = # TODO

print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1])
print("Feature names:", data.feature_names)
print("Target names:", data.target_names)
print("Class distribution:", np.bincount(y))
print("Class 0 = malignant, Class 1 = benign")

# %%
# TODO: Create a DataFrame with feature columns and a 'target' column
df = # TODO

df.head(10)

# %%
# TODO: Use the .describe() method to see basic statistics
# TODO

# %%
# TODO: Use train_test_split() with test_size=0.2, random_state=42, stratify=y
X_train, X_test, y_train, y_test = # TODO

print(f"Train size: {X_train.shape[0]} samples")
print(f"Test size:  {X_test.shape[0]} samples")
print(f"Train class distribution: {np.bincount(y_train)}")
print(f"Test class distribution:  {np.bincount(y_test)}")

# %% [markdown]
# ---
# ## Part 2: Train Classifiers

# %% [markdown]
# ### 2.1 Logistic Regression

# %%
# TODO: Create and train a LogisticRegression model (max_iter=5000)
log_reg = # TODO
# TODO: log_reg.fit(...)

# TODO: Predict on X_test
y_pred_lr = # TODO

print("First 20 predictions:", y_pred_lr[:20])
print("First 20 actual:     ", y_test[:20])

# %% [markdown]
# ### 2.2 K-Nearest Neighbors

# %%
# TODO: Create and train a KNeighborsClassifier (n_neighbors=5)
knn = # TODO
# TODO: knn.fit(...)

# TODO: Predict on X_test
y_pred_knn = # TODO

print("First 20 predictions:", y_pred_knn[:20])
print("First 20 actual:     ", y_test[:20])

# %% [markdown]
# ### 2.3 Gaussian Naive Bayes

# %%
# TODO: Create and train a GaussianNB model
gnb = # TODO
# TODO: gnb.fit(...)

# TODO: Predict on X_test
y_pred_gnb = # TODO

print("First 20 predictions:", y_pred_gnb[:20])
print("First 20 actual:     ", y_test[:20])

# %% [markdown]
# ---
# ## Part 3: Model Evaluation

# %% [markdown]
# ### 3.1 Logistic Regression Evaluation

# %%
# TODO: Compute and print the accuracy score for Logistic Regression
acc_lr = # TODO
print(f"Logistic Regression Accuracy: {acc_lr:.4f}")

# %%
# TODO: Print the classification report for Logistic Regression
# TODO: classification_report(y_test, y_pred_lr, target_names=data.target_names)

# %%
# TODO: Compute and visualize the confusion matrix using seaborn.heatmap
cm_lr = # TODO

# TODO: Use sns.heatmap() to plot it
# TODO

# %% [markdown]
# ### 3.2 KNN Evaluation

# %%
# TODO: Accuracy score for KNN
acc_knn = # TODO
print(f"KNN Accuracy: {acc_knn:.4f}")

# %%
# TODO: Classification report for KNN
# TODO

# %%
# TODO: Confusion matrix heatmap for KNN
# TODO

# %% [markdown]
# ### 3.3 Gaussian Naive Bayes Evaluation

# %%
# TODO: Accuracy score for GaussianNB
acc_gnb = # TODO
print(f"GaussianNB Accuracy: {acc_gnb:.4f}")

# %%
# TODO: Classification report for GaussianNB
# TODO

# %%
# TODO: Confusion matrix heatmap for GaussianNB
# TODO

# %% [markdown]
# ---
# ## Part 4: Comparison and Analysis
#
# Compare the accuracy of all three models.

# %%
# TODO: Create a bar chart comparing the accuracy of all three classifiers
models = ['Logistic Regression', 'KNN', 'GaussianNB']
accuracies = # TODO

# TODO: Use plt.bar() to create the chart
# TODO

# %% [markdown]
# **Written Analysis** (double-click to edit this cell and write your answers):
#
# 1. **Which model performed best?**
#
#    Your answer here...
#
# 2. **Did different models make different types of errors?** (Look at the confusion matrices)
#
#    Your answer here...
#
# 3. **For this dataset, which classifier seems more suitable and why?**
#
#    Your answer here...

# %% [markdown]
# ---
# ## Bonus (Optional)

# %% [markdown]
# ### B1: Cross-Validation
#
# Use cross_val_score instead of a single train/test split for a more reliable estimate.

# %%
# TODO: Use cross_val_score with cv=5 for all three classifiers on the full dataset
# TODO: Print mean and std for each
classifiers = {
    'Logistic Regression': LogisticRegression(max_iter=5000),
    'KNN': KNeighborsClassifier(),
    'GaussianNB': GaussianNB()
}

for name, clf in classifiers.items():
    scores = # TODO: cross_val_score(clf, X, y, cv=5, scoring='accuracy')
    print(f"{name:25s} -> Accuracy: {scores.mean():.4f} (+/- {scores.std():.4f})")

# %% [markdown]
# ### B2: Feature Scaling
#
# Scale features with StandardScaler before KNN and Logistic Regression and check improvement.

# %%
# TODO: Use StandardScaler to fit_transform X_train and transform X_test
scaler = StandardScaler()
X_train_scaled = # TODO
X_test_scaled = # TODO

print("Scaling complete!")
print("Scaled mean:", X_train_scaled.mean(axis=0).round(2)[:5])
print("Scaled std: ", X_train_scaled.std(axis=0).round(2)[:5])

# %%
# TODO: Train and evaluate LogisticRegression and KNN on scaled data
# Compare accuracy before and after scaling

# Logistic Regression on scaled data
log_reg_scaled = LogisticRegression(max_iter=5000)
# TODO: log_reg_scaled.fit(X_train_scaled, y_train)
# TODO: y_pred_lr_scaled = log_reg_scaled.predict(X_test_scaled)
acc_lr_scaled = accuracy_score(y_test, y_pred_lr_scaled)
print(f"LR Accuracy (unscaled): {acc_lr:.4f} -> (scaled): {acc_lr_scaled:.4f}")

# KNN on scaled data
knn_scaled = KNeighborsClassifier()
# TODO: knn_scaled.fit(X_train_scaled, y_train)
# TODO: y_pred_knn_scaled = knn_scaled.predict(X_test_scaled)
acc_knn_scaled = accuracy_score(y_test, y_pred_knn_scaled)
print(f"KNN Accuracy (unscaled): {acc_knn:.4f} -> (scaled): {acc_knn_scaled:.4f}")

# %% [markdown]
# ### B3: Decision Boundary (for two selected features)
#
# Plot the decision boundary for a pair of features using Logistic Regression.

# %%
# TODO: Select two features (e.g., feature indices 0 and 1)
# Train LogisticRegression on just those two features
# Plot the decision boundary using a mesh grid and contourf
# TODO

# %% [markdown]
# ---
# ## Summary
#
# | Task | Class / Function |
# |---|---|
# | Load dataset | `sklearn.datasets.load_breast_cancer()` |
# | Train/test split | `train_test_split()` |
# | Logistic Regression | `LogisticRegression()` |
# | K-Nearest Neighbors | `KNeighborsClassifier()` |
# | Gaussian Naive Bayes | `GaussianNB()` |
# | Evaluation | `accuracy_score()`, `classification_report()`, `confusion_matrix()` |
# | Cross-validation | `cross_val_score()` |
# | Feature scaling | `StandardScaler()` |
